# %%
class Node(object):
    def __init__(self, data):
        self.data = data
        self.next = None
        
class SingleLinkedList(object):
    def __init__(self):
        self.head = None
        self.count = 0
        
    def append(self, node):
        if self.head == None:
            self.head = node
            self.count += 1
        else:
            cur = self.head
            while cur.next is not None:
                cur = cur.next
            cur.next = node
            self.count += 1
    
    def getDataIndex(self, data):
        cur = self.head
        idx = 0
        while cur:
            if cur.data == data:
                return idx
            idx += 1
            cur = cur.next
        return -1
            
    def insertNodeAtIndex(self, node, idx):
        cur_i = 0
        cur = self.head
        if idx == 0:
            node.next = self.head.next
            self.head = node
            return 0
        while cur:
            if cur_i == idx-1:
                node.next = cur.next
                cur.next = node
                return 0
            cur_i += 1
            cur = cur.next
        print('Index Over')
        return -1
    
    def insertNodeAtData():
        a
    
    def print(self):
        cur = self.head
        while cur:
            print(cur.data)
            cur = cur.next
            
        
def main():
    sl =SingleLinkedList()
    sl.append(Node(10))
    sl.append(Node(23))
    sl.append(Node(1))
    sl.append(Node(3))
    sl.append(Node(43))
    sl.append(Node(13))
    sl.insertNodeAtIndex(Node(314), 7)
    sl.print()
    print(sl.getDataIndex(2))
    #print(sl.head.next.data)
    
if __name__=='__main__':
    main()
# Out:
# Index Over
# 10
# 23
# 1
# 3
# 43
# 13
# -1
