# %%
class StackNode(object):
    def __init__(self, data):
        self.data = data
        self.next = None
        
class SingleLinkedList(object):
    def __init__(self):
        self.head = None
        self.count = 0
        
    def append(self, StackNode):
        if self.head == None:
            self.head = StackNode
            self.count += 1
        else:
            cur = self.head
            while cur.next is not None:
                cur = cur.next
            cur.next = StackNode
            self.count += 1
    
    def getDataIndex(self, data):
        cur = self.head
        idx = 0
        while cur:
            if cur.data == data:
                return idx
            idx += 1
            cur = cur.next
        return -1
            
    def insertStackNodeAtIndex(self, StackNode, idx):
        cur_i = 0
        cur = self.head
        if idx == 0:
            StackNode.next = self.head.next
            self.head = StackNode
            return 0
        while cur:
            if cur_i == idx-1:
                StackNode.next = cur.next
                cur.next = StackNode
                return 0
            cur_i += 1
            cur = cur.next
        print('Index Over')
        return -1
    
    def insertStackNodeAtData():
        a
    
    def print(self):
        cur = self.head
        while cur:
            print(cur.data)
            cur = cur.next
            
        
def main():
    sl =SingleLinkedList()
    sl.append(StackNode(10))
    sl.append(StackNode(23))
    sl.append(StackNode(1))
    sl.append(StackNode(3))
    sl.append(StackNode(43))
    sl.append(StackNode(13))
    sl.insertStackNodeAtIndex(StackNode(314), 7)
    sl.print()
    print(sl.getDataIndex(2))
    #print(sl.head.next.data)
    
if __name__=='__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-568b0902fd53> in <module>
#      71
#      72 if __name__=='__main__':
# ---> 73     main()
#      74
#      75
#
# <ipython-input-1-568b0902fd53> in main()
#      59 def main():
#      60     sl =SingleLinkedList()
# ---> 61     sl.append(SNode(10))
#      62     sl.append(SNode(23))
#      63     sl.append(SNode(1))
#
# NameError: name 'SNode' is not defined
