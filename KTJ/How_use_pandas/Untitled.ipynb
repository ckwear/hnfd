# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 300) 
data_sit = pd.read_csv(r'sitDB.csv')
print(data_sit.loc[10, 'SpineBase_x'])
data_sit
for i in range(len(data_sit.index)):
    print(i, data_sit.loc[i, 'SpineBase_x'])

data_sit
# Out:
# -0.189305
# 0 -1.2860040000000001
# 1 -0.6907704000000001
# 2 -0.2371071
# 3 -0.2306189
# 4 -0.20528520000000003
# 5 -0.1993594
# 6 -0.19871770000000002
# 7 -0.1945954
# 8 -0.1942539
# 9 -0.1931025
# 10 -0.189305
# 11 -0.18724520000000003
# 12 -0.1645844
# 13 -0.12684389999999998
# 14 -0.12523430000000002
# 15 -0.06486039
# 16 -0.0627972
# 17 -0.06100904
# 18 -0.06092627
# 19 -0.05952948
# 20 -0.04351429
# 21 -0.03241452
# 22 -0.014674600000000001
# 23 0.002323281
# 24 0.00763863
# 25 0.02744025
# 26 0.02906981
# 27 0.03120275
# 28 0.031235500000000003
# 29 0.03229889
# 30 0.03273448
# 31 0.03964692
# 32 0.05589658
# 33 0.05674236
# 34 0.05725567
# 35 0.058826800000000005
# 36 0.06431802
# 37 0.06557751
# 38 0.0772479
# 39 0.07926568
# 40 0.0846822
# 41 0.09353855
# 42 0.1136769
# 43 0.13776029999999997
# 44 0.1418649
# 45 0.14225179999999998
# 46 0.1485901
# 47 0.1537321
# 48 0.16567089999999998
# 49 0.1670491
# 50 0.1798402
# 51 0.1822375
# 52 0.1834059
# 53 0.18659320000000001
# ...

# %%
import math
a = 12385239522334
b = 234235
c = a
c *= (10**(int(math.log10(b)) + 1))
print(math.log(123))
# Out:
# 4.812184355372417

# %%
a = 'LA30-52E'
print(ord('1'))
print()
for c in a:
    if 48 <= ord(c) <= 58:
        print(c)
# Out:
# 49
#
# 3
# 0
# 5
# 2
