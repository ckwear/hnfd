# %%
import pymysql
import pandas as pd
conn = pymysql.connect(host='127.0.0.1', user='markcha', password='12ektm', db='django', charset='utf8')
curs = conn.cursor()
 
# SQL문 실행
sql = "select * from order_paper where due_date='2019-11-05 00:00:00' AND factory_num='용인2';"
curs.execute(sql)
df = pd.DataFrame([1,2,3,4,3])
df = pd.DataFrame()
print(df)
# 데이타 Fetch
rows = curs.fetchall()
print(rows)     # 전체 rows
# print(rows[0])  # 첫번째 row: (1, '김정수', 1, '서울')
# print(rows[1])  # 두번째 row: (2, '강수정', 2, '서울')
 
# Connection 닫기
conn.close()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# ...
