# %%
import telegram
import time

chat_token = "1271852396:AAEltk0PRTeMy0fEQv1geYZd-DqjK-ugnZQ"
chat = telegram.Bot(token = chat_token)
updates = chat.getUpdates()
print(updates)
for u in updates:
    print(u.message)
    print(u.message['chat']['id'])
# Out:
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# []

# %%
import time
import telepot

def handle(msg):
    content_type, chat_type, chat_id = telepot.glance(msg)
    print(content_type, chat_type, chat_id)
#     if content_type=='text':
#         bot.sendMessage(chat_id, msg['text'])
        
        
bot = telepot.Bot("1271852396:AAEltk0PRTeMy0fEQv1geYZd-DqjK-ugnZQ")
bot.message_loop(handle)
print('ww')

while 1:
    time.sleep(10)
# Out:
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# ww
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# text private 1054497621
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# Traceback (most recent call last):
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1183, in get_from_telegram_server
#     allowed_updates=allowed_upd)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 155, in request
#     return _parse(r)
#   File "/home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/telepot/api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Conflict: terminated by other getUpdates request; make sure that only one bot instance is running', 409, {'ok': False, 'error_code': 409, 'description': 'Conflict: terminated by other getUpdates request; make sure that only one bot instance is running'})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-91a5d9d88aba> in <module>
#      14
#      15 while 1:
# ---> 16     time.sleep(10)
#
# KeyboardInterrupt:
