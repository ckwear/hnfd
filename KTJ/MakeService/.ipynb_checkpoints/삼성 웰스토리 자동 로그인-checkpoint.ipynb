# %%
from threading import Thread
from os import system
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import ElementNotVisibleException
from bs4 import BeautifulSoup
import time

#aa = webdriver.Chrome('/home/markcha/PycharmProjects/service/chromedriver')#
#aa.get('https://google.com')
#aa.f

def main():
    driver = "./chromedriver"

    options = webdriver.ChromeOptions()
    # options.add_argument('headless')
    #options.add_argument("disable-gpu")
    options.add_argument("lang=ko_KR")  # 한국어!
    options.add_argument(
        "user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")

    options.add_experimental_option("prefs", {
        "download.default_directory": r"/home/markcha/hanulfood",
        "download.prompt_for_download": False,
        "download.directory_upgrade": True,
        "safebrowsing.enabled": True
    })

    driver = webdriver.Chrome('./chromedriver',chrome_options=options)
    driver.implicitly_wait(30)
    url = 'https://srm.welstory.com/splogin.do'
    driver.get(url)
    id_form = driver.find_element_by_xpath('//*[@id="id"]')
    id_form.send_keys('1238133948')
    pw_form = driver.find_element_by_xpath('//*[@id="pw"]')
    pw_form.send_keys('tel5007**2')
    driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/form/div[1]/a').click()
    req = driver.page_source
    soup=BeautifulSoup(req, 'html.parser')
    information_list = soup.select(".subject2")
    stat = information_list[0].text
    if '실패' in stat:
        pass
    else:
        driver.find_element_by_xpath('/html/body/sc-messagebox/sc-toolbar[2]/sc-button').click()
        cnt_window = driver.find_element_by_xpath('/html/body/sc-window')
        for i in range(len(cnt_window) - 1):
            cnt_window = driver.find_element_by_xpath('/html/body/sc-window[{0}]/sc-toolbar/sc-button[3]'.format(i+1)).click()
        
        
        
        
        driver.find_element_by_xpath('/html/body/sc-mdi/div[1]/div[2]/sc-mdi-topmenu/div[1]/ul/li[4]/a/span').click()
        driver.find_element_by_xpath('/html/body/sc-mdi/div[1]/div[2]/sc-mdi-topmenu/div[2]/ul/li[1]"]').click()
        driver.find_element_by_xpath('/html/body/sc-mdi/div[1]/div[2]/sc-mdi-topmenu/div[2]/ul/li[1]/ul/li[4]/a/span').click()
'''
//*[@id="sc-button-9"]

//*[@id="sc-button-49"]
/html/body/sc-window[8]/sc-toolbar/sc-button[3]

//*[@id="sc-button-44"]
/html/body/sc-window[7]/sc-toolbar/sc-button[3]

//*[@id="sc-button-39"]
/html/body/sc-window[6]/sc-toolbar/sc-button[3]

//*[@id="sc-button-34"]
/html/body/sc-window[5]/sc-toolbar/sc-button[3]

//*[@id="sc-button-29"]
/html/body/sc-window[4]/sc-toolbar/sc-button[3]

//*[@id="sc-button-24"]
/html/body/sc-window[3]/sc-toolbar/sc-button[3]

//*[@id="sc-button-19"]
/html/body/sc-window[2]/sc-toolbar/sc-button[3]

//*[@id="sc-button-14"]
/html/body/sc-window[1]/sc-toolbar/sc-button[3]


//*[@id="sc-window-25"]
/html/body/sc-window[3]






'''
    
if __name__ == '__main__':
    main()
# Out:
# /home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/ipykernel_launcher.py:31: DeprecationWarning: use options instead of chrome_options
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-2c9738e456fd> in <module>
#      92
#      93 if __name__ == '__main__':
# ---> 94     main()
#
# <ipython-input-32-2c9738e456fd> in main()
#      39     driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/form/div[1]/a').click()
#      40
# ---> 41     if '실패' in stat:
#      42         pass
#      43     else:
#
# NameError: name 'stat' is not defined

# %%
import schedule 
import time 

def job(): 
    print("I'm working...")
    
schedule.every().day.at("3:34").do(job)

schedule.every().day.at("10:30").do(job)
# Out:
# ---------------------------------------------------------------------------
# ScheduleValueError                        Traceback (most recent call last)
# <ipython-input-48-1435fc4369d0> in <module>
#       5     print("I'm working...")
#       6
# ----> 7 schedule.every().day.at("3:34").do(job)
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/schedule/__init__.py in at(self, time_str)
#     379         if self.unit == 'days' or self.start_day:
#     380             if not re.match(r'^([0-2]\d:)?[0-5]\d:[0-5]\d$', time_str):
# --> 381                 raise ScheduleValueError('Invalid time format')
#     382         if self.unit == 'hours':
#     383             if not re.match(r'^([0-5]\d)?:[0-5]\d$', time_str):
#
# ScheduleValueError: Invalid time format

# %%
from threading import Thread
from os import system
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import ElementNotVisibleException
from bs4 import BeautifulSoup
import time

#aa = webdriver.Chrome('/home/markcha/PycharmProjects/service/chromedriver')#
#aa.get('https://google.com')
#aa.f

def main():
    driver = "./chromedriver"

    options = webdriver.ChromeOptions()
    # options.add_argument('headless')
    #options.add_argument("disable-gpu")
    options.add_argument("lang=ko_KR")  # 한국어!
    options.add_argument(
        "user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")

    options.add_experimental_option("prefs", {
        "download.default_directory": r"/home/markcha/hanulfood",
        "download.prompt_for_download": False,
        "download.directory_upgrade": True,
        "safebrowsing.enabled": True
    })

    driver = webdriver.Chrome('./chromedriver',chrome_options=options)
    driver.implicitly_wait(30)
    url = 'https://srm.welstory.com/splogin.do'
    driver.get(url)
    id_form = driver.find_element_by_xpath('//*[@id="id"]')
    id_form.send_keys('1238133948')
    pw_form = driver.find_element_by_xpath('//*[@id="pw"]')
    pw_form.send_keys('tel5007**2')
    driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/form/div[1]/a').click()


    driver.find_element_by_xpath('/html/body/sc-messagebox/sc-toolbar[2]/sc-button').click()
    cnt_window = driver.find_elements_by_xpath('/html/body/sc-window')
    cnt = len(cnt_window)
    for i in range(cnt):
        cnt_window = driver.find_element_by_xpath('/html/body/sc-window[%d]/sc-toolbar/sc-button[3]' %(cnt - i)).click()
        
    time.sleep(10)
    driver.find_element_by_xpath('/html/body/sc-mdi/div[1]/div[2]/sc-mdi-topmenu/div[1]/ul/li[4]/a/span').click()
    driver.find_element_by_xpath('/html/body/sc-mdi/div[1]/div[2]/sc-mdi-topmenu/div[2]/ul/li[1]/a/span').click()
    driver.find_element_by_xpath('/html/body/sc-mdi/div[1]/div[2]/sc-mdi-topmenu/div[2]/ul/li[1]/ul/li[4]/a/span').click()
        
    #1차소분만 선택
    driver.find_element_by_xpath('/html/body/sc-mdi/div[2]/sc-mdi-content/sc-pages/sc-mdi-window[2]/em-fc-po-list/sc-pages/es-fc-po-list/cc-search-container/div[1]/div[1]/table/tbody/tr[2]/td[3]/div/sc-checkbox-field[2]/div').click()
        
    #엑셀 다운로드 버튼
    driver.find_element_by_xpath('/html/body/sc-mdi/div[2]/sc-mdi-content/sc-pages/sc-mdi-window[2]/em-fc-po-list/sc-pages/es-fc-po-list/sc-grid/div/div/cc-grid-toolbar/div[1]/div[1]/ul/li[1]/button').click()
    driver.find_element_by_xpath('/html/body/sc-messagebox/sc-toolbar[2]/sc-button[1]').click()
        
    #용인 선택
    driver.find_element_by_xpath('/html/body/sc-mdi/div[2]/sc-mdi-content/sc-pages/sc-mdi-window[2]/em-fc-po-list/sc-pages/es-fc-po-list/cc-search-container/div[1]/div[1]/table/tbody/tr[1]/td[1]/cc-operorg-plt-combobox-field/div/sc-combobox-field[2]/div/div[2]/div').click()
    driver.find_element_by_xpath('/html/body/sc-dropdown/sc-listbox/div[6]').click()
        
    #엑셀 다운로드 버튼
    driver.find_element_by_xpath('/html/body/sc-mdi/div[2]/sc-mdi-content/sc-pages/sc-mdi-window[2]/em-fc-po-list/sc-pages/es-fc-po-list/sc-grid/div/div/cc-grid-toolbar/div[1]/div[1]/ul/li[1]/button').click()
    driver.find_element_by_xpath('/html/body/sc-messagebox/sc-toolbar[2]/sc-button[1]').click()
        
'''
//*[@id="sc-button-9"]

//*[@id="sc-button-49"]
/html/body/sc-window[8]/sc-toolbar/sc-button[3]

//*[@id="sc-button-44"]
/html/body/sc-window[7]/sc-toolbar/sc-button[3]

//*[@id="sc-button-39"]
/html/body/sc-window[6]/sc-toolbar/sc-button[3]

//*[@id="sc-button-34"]
/html/body/sc-window[5]/sc-toolbar/sc-button[3]

//*[@id="sc-button-29"]
/html/body/sc-window[4]/sc-toolbar/sc-button[3]

//*[@id="sc-button-24"]
/html/body/sc-window[3]/sc-toolbar/sc-button[3]

//*[@id="sc-button-19"]
/html/body/sc-window[2]/sc-toolbar/sc-button[3]

//*[@id="sc-button-14"]
/html/body/sc-window[1]/sc-toolbar/sc-button[3]


//*[@id="sc-window-25"]
/html/body/sc-window[3]




/html/body/sc-window[7]/sc-toolbar/sc-button[3]

'''
    
if __name__ == '__main__':
    main()
# Out:
# /home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/ipykernel_launcher.py:31: DeprecationWarning: use options instead of chrome_options

# %%
from threading import Thread
from os import system
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import ElementNotVisibleException
from bs4 import BeautifulSoup
import time

#aa = webdriver.Chrome('/home/markcha/PycharmProjects/service/chromedriver')#
#aa.get('https://google.com')
#aa.f

def main():
    driver = "./chromedriver"

    options = webdriver.ChromeOptions()
    # options.add_argument('headless')
    #options.add_argument("disable-gpu")
    options.add_argument("lang=ko_KR")  # 한국어!
    options.add_argument(
        "user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")

    options.add_experimental_option("prefs", {
        "download.default_directory": r"/home/markcha/hanulfood",
        "download.prompt_for_download": False,
        "download.directory_upgrade": True,
        "safebrowsing.enabled": True
    })

    driver = webdriver.Chrome('./chromedriver',chrome_options=options)
    driver.implicitly_wait(30)
    url = 'https://www.google.com/'
    driver.get(url)
    
    id_form = driver.find_element_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[1]/div/div[2]/input')
    id_form.send_keys('반디집')
    id_form.send_keys(Keys.ENTER)
    driver.find_element_by_xpath('//*[@id="rso"]/div[2]/div/div[1]/a/h3').click()
    req = driver.page_source
    soup=BeautifulSoup(req, 'html.parser')
    print(soup)
    
if __name__ == '__main__':
    main()
# Out:
# /home/markcha/anaconda3/envs/py366/lib/python3.6/site-packages/ipykernel_launcher.py:31: DeprecationWarning: use options instead of chrome_options
# <html lang="ko" xml:lang="ko"><head>
# <meta charset="utf-8"/>
# <meta content="Bandisoft" name="author"/>
# <meta content="반디소프트,반디집,맥 반디집,꿀캠,꿀뷰,허니캠,반디카메라,허니뷰" name="keywords"/>
# <meta content="반디소프트 홈페이지" name="description"/>
# <meta content="width=device-width, user-scalable=yes" name="viewport"/>
# <title>반디소프트</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://www.bandisoft.com/" rel="canonical"/>
# <link href="https://www.bandisoft.com/" hreflang="x-default" rel="alternate"/>
# <link href="https://kr.bandisoft.com/" hreflang="ko" rel="alternate"/>
# <link href="https://en.bandisoft.com/" hreflang="en" rel="alternate"/>
# <link href="https://cn.bandisoft.com/" hreflang="zh-hans" rel="alternate"/>
# <link href="https://tw.bandisoft.com/" hreflang="zh-hant" rel="alternate"/>
# ...
