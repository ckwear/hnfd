# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

pymysql.install_as_MySQLdb()
import MySQLdb


# 가구원수 = pd.read_csv('가구원수.csv', engine='python')
# 가구원수.rename (columns = { 
#     '행 레이블': 'row',
#     '특성': 'pp_num',
#     '합계 : 2019 응답자수': 'num'
# }, inplace = True)


# 가구원수

# 가구원수.to_sql(name = 'fm_pp_num', con=engine)


가구주성 = pd.read_csv('가구주성.csv', engine='python')
가구주성.rename (columns = { 
    '행 레이블': 'row',
    '특성': 'sex',
    '합계 : 2019 응답자수': 'num'
}, inplace = True)


가구주성


가구주성.to_sql(name = 'fm_sex', con=engine)



가구주연령 = pd.read_csv('가구주연령.csv', engine='python')
가구주연령.rename (columns = { 
    '행 레이블': 'row',
    '특성': 'age',
    '합계 : 2019 응답자수': 'num'
}, inplace = True)


가구주연령

가구주연령.to_sql(name = 'fm_age', con=engine)




가구주종사상지위 = pd.read_csv('가구주종사상지위.csv', engine='python')
가구주종사상지위.rename (columns = { 
    '행 레이블': 'row',
    '특성': 'job',
    '합계 : 2019 응답자수': 'num'
}, inplace = True)


가구주종사상지위


가구주종사상지위.to_sql(name = 'fm_job', con=engine)




가구주혼인상태 = pd.read_csv('가구주혼인상태.csv', engine='python')
가구주혼인상태.rename (columns = { 
    '행 레이블': 'row',
    '특성': 'cond',
    '합계 : 2019 응답자수': 'num'
}, inplace = True)


가구주혼인상태


가구주혼인상태.to_sql(name = 'fm_cond', con=engine)


교육수준 = pd.read_csv('교육수준.csv', engine='python')
교육수준.rename (columns = { 
    '행 레이블': 'row',
    '특성': 'learn',
    '합계 : 2019 응답자수': 'num'
}, inplace = True)


교육수준


교육수준.to_sql(name = 'fm_learn', con=engine)




교육수준 = pd.read_csv('교육수준.csv', engine='python')
교육수준.rename (columns = { 
    '행 레이블': 'row',
    '특성': 'learn',
    '합계 : 2019 응답자수': 'num'
}, inplace = True)


교육수준


교육수준.to_sql(name = 'fm_learn', con=engine)


순자산 = pd.read_csv('순자산.csv', engine='python')
순자산.rename (columns = { 
    '행 레이블': 'row',
    '특성': 'money',
    '합계 : 2019 응답자수': 'num'
}, inplace = True)


순자산
순자산.to_sql(name = 'fm_money', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-697abe593832> in <module>
#     107
#     108
# --> 109 교육수준.to_sql(name = 'fm_learn', con=engine)
#     110
#     111
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~/anaconda3/envs/py366/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ...

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

pymysql.install_as_MySQLdb()
import MySQLdb


가구원수 = pd.read_csv('./가구원수.csv', engine='python')
가구원수.rename (columns = { 
    '행 레이블': 'row',
    '특성': 'pp_num',
    '합계 : 2019 응답자수': 'num'
}, inplace = True)


가구원수

engine = create_engine("mysql+mysqldb://markcha:"+"12ektm"+"@localhost/r2", encoding='utf-8')
conn = engine.connect()
가구원수.to_sql(name = 'fm_pp_num', con=engine)
