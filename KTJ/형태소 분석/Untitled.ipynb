# %%
import konlpy
from konlpy.tag import Kkma
from konlpy.utils import pprint
kkma = Kkma()
text = '''
출전한 모든 선수가 상금을 받는다. 꼴찌를 해도 약 6000만원이다. 컷탈락 없이 치러지는 미국프로골프(PGA) 투어 초특급대회 월드골프챔피언십(WGC) 페덱스 세인트 주드 인비테이셔널이 30일(현지시간)부터 나흘동안 미국 테네시주 멤피스 근교 TPC사우스윈드(파70)에서 개막, ‘쩐의전쟁’이 펼쳐진다.

 

4대 메이저 대회와 ‘제5의 메이저’ 플레이어스 챔피언십을 방불케 한다. 총상금 1050만달러(약 125억6325만원)에 우승상금은 174만5000달러(약 20억8789만원)에 달한다. 하지만 출전 선수는 78명뿐이고 컷탈락은 없다. 상금이 큰 만큼 톱랭커 들이 총출동하는데 세계랭킹 50위 이내 선수 가운데 45명이 출전명단에 이름을 올렸다. 세계랭킹 10위 이내 선수중 9위 애덤 스콧(40·호주) 한명만 빠졌다. 세계랭킹 15위이자 이 대회에서 무려 8차례 우승한 ‘골프 황제’ 타이거 우즈(45·미국)도 쉬어간다. 시즌 첫 번째 메이저대회인 PGA 챔피언십에 집중한다는 전략을 짜고 있기 때문이다.

 

따라서 자연스럽게 시선은 세계랭킹 1위를 둘러싼 욘 람(26·스페인)과 로리 매킬로이(31·북아일랜드)의 자존심 대결에 모아진다. 욘 람은 2주전 메모리얼 토너먼트 우승으로 매킬로이를 밀어내고 생애 처음으로 세계랭킹 1위 자리에 섰다. 장기 집권의 발판을 다지려면 이번 대회에서도 톱10에 진입하는 것이 중요하다.

 

매킬로이는 시즌 초반에는 빼어난 활약을 보였다. WGC HSBC챔피언스에서 시즌 첫 승을 올렸고 조조 챔피언십, 파머스 인슈어런스 오픈 공동 3위 등 6개 대회에 출전해 모두 톱5에 들었다. 하지만 코코로나19로 중단됐던 PGA 투어가 3개월만에 재개된 뒤에는 샷이 많이 무뎌졌다. 4개 대회에 출전했지만 공동 32위, 41위, 11위, 32위의 성적을 내며 톱10에도 이름을 올리지 못하는 상황이다. 이 때문에 세계랭킹 1위 자리를 욘 람에게 내줬다. 매킬로이는 2014년 이 대회 우승 경험을 살려 정상탈환에 나선다는 각오다. 
'''

print(kkma.nouns(text))
okt = konlpy.tag.Okt() 
# print(okt.morphs(text))

# text = '유일하게 항공기 체계 종합개발 경험을 갖고 있는 KAI는 단독입찰보다 복수입찰의 경우 이것도 되나욬ㅋㅋ'

okt = konlpy.tag.Okt()

for word in okt.pos(text):
    if word[1] in ['Noun']:
#         pass
        print(word[0])
        
        

        
        
#ext = '유일하게 항공기 체계 종합개발 경험을 갖고 있는 KAI는 단독입찰보다 복수입찰의 경우 이것도 되나욬ㅋㅋ'

okt = konlpy.tag.Okt()

for word in okt.pos(text): 
    if word[1] in ['Noun', 'Verb', 'Adjective']: #명사, 동사, 형용사
#         pass
        print(word[0])
# Out:
# ['출전', '모든', '선수', '상금', '꼴찌', '약', '6000', '6000만원', '만', '원', '컷', '컷탈락', '탈락', '미국', '미국프로골프', '프로', '골프', '투어', '초특급', '초특급대회', '대회', '월드', '월드골프챔피언십', '챔피언십', '페덱스', '세인트', '주드', '테', '널이', '30', '30일', '일', '현지', '현지시간', '시간', '나흘', '나흘동안', '동안', '테네시', '테네시주', '주', '멤피스', '근교', '사우스', '사우스윈드', '윈드', '파', '파70', '70', '개막', '의', '의전쟁', '전쟁', '이', '4', '4대', '대', '메이저', '저', '5', '플레이', '플레이어스', '어스', '총상', '총상금', '금', '1050', '1050만달러', '달러', '125', '125억6325만', '억', '6325', '우승', '우승상금', '174', '174만5000달러', '5000', '20', '20억8789만', '8789', '78', '78명', '명', '만큼', '톱', '톱랭', '랭', '들', '총출동', '세계', '세계랭킹', '랭킹', '50', '50위', '위', '이내', '가운데', '45', '45명', '출전명단', '명단', '이름', '10', '10위', '선수중', '중', '9', '9위', '애', '애덤', '덤', '스콧', '40', '호주', '한명', '15', '15위이자', '이자', '8', '8차례', '차례', '황제', '타이거', '우', '우즈', '즈', '도', '시즌', '번째', '메이저대회', '집중', '전략', '때문', '자연', '시선', '1', '1위', '욘', '람', '26', '스페인', '과', '로', '로리', '리', '매', '로이', '31', '북', '북아일랜드', '아일랜드', '자존심', '대결', 
# ...
